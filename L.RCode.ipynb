# %%
import pandas as pd
from pandas.api.types import CategoricalDtype
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn import preprocessing

# %%
#Read DataSet off of computer
df = pd.read_csv('C:/Users/jefft/Desktop/WGU Classes/D208/medical_clean.csv', index_col=0)

# %%
#Summary Statisticts for Dependent y Variable initial_days
df.Initial_days.describe()
# Out:
# count    10000.000000
# mean        34.455299
# std         26.309341
# min          1.001981
# 25%          7.896215
# 50%         35.836244
# 75%         61.161020
# max         71.981490
# Name: Initial_days, dtype: float64

# %%
df.Initial_days.nlargest()
# Out:
# CaseOrder
# 7969    71.98149
# 5327    71.96869
# 7480    71.96546
# 6167    71.96415
# 8067    71.96342
# Name: Initial_days, dtype: float64

# %%
df.Initial_days.value_counts()
# Out:
# Initial_days
# 63.544320    2
# 67.421390    2
# 70.325420    2
# 63.334690    1
# 67.036510    1
#             ..
# 5.977596     1
# 5.799041     1
# 6.415853     1
# 7.328631     1
# 70.850590    1
# Name: count, Length: 9997, dtype: int64

# %%
df.Initial_days.nsmallest()
# Out:
# CaseOrder
# 1748    1.001981
# 2509    1.008401
# 4996    1.009143
# 4427    1.010068
# 4818    1.012481
# Name: Initial_days, dtype: float64

# %%
#Summary Statisticts For Independent Variables Children, Anxiety,Age,Income, Gender, Vitd_levels,arthritis,Diabetes, Total Charge,Doc_visits. 
df.Children.describe()
# Out:
# count    10000.000000
# mean         2.097200
# std          2.163659
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          3.000000
# max         10.000000
# Name: Children, dtype: float64

# %%
df.Children.value_counts().sort_index()
# Out:
# Children
# 0     2548
# 1     2509
# 2     1475
# 3     1489
# 4      995
# 5      169
# 6      191
# 7      213
# 8      209
# 9      108
# 10      94
# Name: count, dtype: int64

# %%
df.Children.nsmallest()
# Out:
# CaseOrder
# 4     0
# 7     0
# 9     0
# 13    0
# 18    0
# Name: Children, dtype: int64

# %%
df.Children.nlargest()
# Out:
# CaseOrder
# 17     10
# 157    10
# 181    10
# 186    10
# 220    10
# Name: Children, dtype: int64

# %%
#summary statistics for Anxiety
df.Anxiety.describe()
# Out:
# count     10000
# unique        2
# top          No
# freq       6785
# Name: Anxiety, dtype: object

# %%
df.Anxiety.value_counts().sort_index()
# Out:
# Anxiety
# No     6785
# Yes    3215
# Name: count, dtype: int64

# %%
#summary Statistics for Age
df.Age.describe()
# Out:
# count    10000.000000
# mean        53.511700
# std         20.638538
# min         18.000000
# 25%         36.000000
# 50%         53.000000
# 75%         71.000000
# max         89.000000
# Name: Age, dtype: float64

# %%
df.Age.value_counts().sort_index()
# Out:
# Age
# 18    133
# 19    137
# 20    120
# 21    125
# 22    141
#      ...
# 85    135
# 86    156
# 87    136
# 88    143
# 89    132
# Name: count, Length: 72, dtype: int64

# %%
#summary Statistics for Income
df.Income.describe()
# Out:
# count     10000.000000
# mean      40490.495160
# std       28521.153293
# min         154.080000
# 25%       19598.775000
# 50%       33768.420000
# 75%       54296.402500
# max      207249.100000
# Name: Income, dtype: float64

# %%
df.Income.nlargest()
# Out:
# CaseOrder
# 8387    207249.10
# 842     204542.41
# 8599    203774.60
# 6407    197675.00
# 1779    197576.18
# Name: Income, dtype: float64

# %%
df.Income.nsmallest()
# Out:
# CaseOrder
# 822     154.08
# 9809    300.79
# 288     395.23
# 111     401.86
# 8659    493.04
# Name: Income, dtype: float64

# %%
#summary Statistics for Gender
df.Gender.describe()
# Out:
# count      10000
# unique         3
# top       Female
# freq        5018
# Name: Gender, dtype: object

# %%
df.Gender.value_counts()
# Out:
# Gender
# Female       5018
# Male         4768
# Nonbinary     214
# Name: count, dtype: int64

# %%
#Summary Statistics for Vitd_levels
df.VitD_levels.describe()
# Out:
# count    10000.000000
# mean        17.964262
# std          2.017231
# min          9.806483
# 25%         16.626439
# 50%         17.951122
# 75%         19.347963
# max         26.394449
# Name: VitD_levels, dtype: float64

# %% [raw]
# #summary Statistics for Arthritis

# %%
df.Arthritis.describe()
# Out:
# count     10000
# unique        2
# top          No
# freq       6426
# Name: Arthritis, dtype: object

# %%
df.Arthritis.value_counts()
# Out:
# Arthritis
# No     6426
# Yes    3574
# Name: count, dtype: int64

# %%
#summary Statistics for Diabetes
df.Diabetes.describe()
# Out:
# count     10000
# unique        2
# top          No
# freq       7262
# Name: Diabetes, dtype: object

# %%
df.Diabetes.value_counts()
# Out:
# Diabetes
# No     7262
# Yes    2738
# Name: count, dtype: int64

# %%
#summary Statistics for Total Charge
df.TotalCharge.describe()
# Out:
# count    10000.000000
# mean      5312.172769
# std       2180.393838
# min       1938.312067
# 25%       3179.374015
# 50%       5213.952000
# 75%       7459.699750
# max       9180.728000
# Name: TotalCharge, dtype: float64

# %%
df.TotalCharge.nlargest()
# Out:
# CaseOrder
# 5713    9180.728
# 8988    9169.248
# 5501    9080.912
# 9404    9077.388
# 5462    9067.605
# Name: TotalCharge, dtype: float64

# %%
df.TotalCharge.nsmallest()
# Out:
# CaseOrder
# 2509    1938.312067
# 3655    1957.445547
# 2496    1969.472468
# 4213    2000.776336
# 3086    2004.755279
# Name: TotalCharge, dtype: float64

# %%
#summary Statistics for Doc_visits
df.Doc_visits.describe()
# Out:
# count    10000.000000
# mean         5.012200
# std          1.045734
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          6.000000
# max          9.000000
# Name: Doc_visits, dtype: float64

# %%
df.Doc_visits.nlargest()
# Out:
# CaseOrder
# 963     9
# 2767    9
# 240     8
# 597     8
# 620     8
# Name: Doc_visits, dtype: int64

# %%
#Summary Statistics for BackPain
df.BackPain.describe()
# Out:
# count     10000
# unique        2
# top          No
# freq       5886
# Name: BackPain, dtype: object

# %%
#Backpain,Avg_daily_charge
df.BackPain.value_counts()
# Out:
# BackPain
# No     5886
# Yes    4114
# Name: count, dtype: int64

# %%
# Convert specified columns from string to category
df["TimeZone"] = df["TimeZone"].astype("category")
df["Marital"] = df["Marital"].astype("category")
df["Gender"] = df["Gender"].astype("category")
df["Initial_admin"] = df["Initial_admin"].astype("category")
df["Complication_risk"] = df["Complication_risk"].astype("category")
df["Services"] = df["Services"].astype("category")

# Reformat the 'Income' column from float to integer
df["Income"] = df["Income"].astype(int)

# Reformat currency columns to 3 decimal places
df["TotalCharge"] = df["TotalCharge"].round(3)
df["Additional_charges"] = df["Additional_charges"].round(3)

# Define mapping for boolean conversion
bool_mapping = {"Yes": 1, "No": 0}

# Convert specified columns from string to boolean using the mapping
boolean_columns = ["ReAdmis", "Soft_drink", "HighBlood", "Stroke", "Overweight", 
                   "Arthritis", "Diabetes", "Hyperlipidemia", "BackPain", "Anxiety", 
                   "Allergic_rhinitis", "Reflux_esophagitis", "Asthma"]

for col in boolean_columns:
    df[col] = df[col].map(bool_mapping)

# Define mapping to reverse survey scores
survey_mapping = {1: 8, 2: 7, 3: 6, 4: 5, 5: 4, 6: 3, 7: 2, 8: 1}

# Define ordered categorical datatype for survey responses
survey_scores = CategoricalDtype(categories=["1", "2", "3", "4", "5", "6", "7", "8"], ordered=True)

# Reverse and convert survey score columns to ordered categorical datatype
survey_columns = ["Item1", "Item2", "Item3", "Item4", "Item5", "Item6", "Item7", "Item8"]

for col in survey_columns:
    df[col] = df[col].map(survey_mapping).map(str).astype(survey_scores)

# %%
##Univariate and Bivariate Distributions
# Dependent
plt.subplot(1, 2, 1)
plt.title('Initial Days Exploration')
bins = np.arange(0, 74, 1)
plt.hist(data=df, x="Initial_days", bins=bins)
plt.xlabel('Days in Hospital')
plt.ylabel("Number of Patients");

# %%
#Each Independent Variables Univariate Exploration and Bivariate exploaration vs Initial_days
plt.figure(figsize = [16,5])
plt.suptitle("Exploration of Number of Children in Patient's Household")
plt.subplot(1, 2, 1)
plt.title('Distribution of Children in Patient Household')
bins = np.arange(0, df.Children.max() + 1, 1)
plt.hist(data=df, x="Children", bins=bins)
plt.xlabel('Number of Children')
plt.ylabel("Number of Patients");
plt.subplot(1, 2, 2)
plt.title(" Children vs Initial Days")
sns.regplot(data=df, x="Children", y="Initial_days", x_jitter=0.3, scatter_kws={'alpha' : 1/10})
plt.xlabel("Number of Children")
plt.ylabel("Initial Days");

# %%
plt.figure(figsize = [16,5])
plt.suptitle("Exploration of Patient's Age")
plt.subplot(1, 2, 1)
plt.title(' Patient Age')
bins = np.arange(0, 100, 1)
plt.hist(data=df, x="Age", bins=bins)
plt.xlabel('Patient Age')
plt.ylabel("Number of Patients");
plt.subplot(1, 2, 2)
plt.title("Relationship of Age vs Initial Days")
sns.regplot(data=df, x="Age", y="Initial_days", scatter_kws={'alpha' : 1/10})
plt.xlabel("Patient Age")
plt.ylabel("Initial Days");

# %%
plt.figure(figsize = [16,5])
plt.suptitle("Exploration of Patient's Income")
plt.subplot(1, 2, 1)
plt.title('Distribution of Patient Income')
bins = np.arange(0,df.Income.max() + 1000, 1000)
plt.hist(data=df, x="Income", bins=bins)
plt.xlabel('Patient Income')
plt.ylabel("Number of Patients");
plt.subplot(1, 2, 2)
plt.title("Relationship of Income vs Initial Days")
sns.regplot(data=df, x="Income", y="Initial_days", scatter_kws={'alpha' : 1/10})
plt.xlabel("Patient Income")
plt.ylabel("Initial Days");

# %%
plt.figure(figsize = [16,5])
plt.suptitle("Exploration of Patient's Gender")
plt.subplot(1, 2, 1)
plt.title("Patient Gender Distribution")
gender_counts = df["Gender"].value_counts()
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90, counterclock = False)
plt.axis('square');
plt.subplot(1, 2, 2)
plt.title("Relationship of Gender vs Initial Days")
sns.boxplot(data=df, x="Gender", y='Initial_days', color="purple")
plt.xlabel("Patient Gender")
plt.ylabel("Initial Days");
# Out:
# C:\Users\jefft\anaconda3\envs\JeffPandasNumpy\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
plt.figure(figsize = [16,5])
plt.suptitle("Exploration of Patients with Chronic Back Pain")
plt.subplot(1, 2, 1)
plt.title('Distribution of Patients with Chronic Back Pain')
back_pain_counts = df.BackPain.value_counts()
back_pain_labels = ["No Back Pain", "Back Pain"]
plt.pie(back_pain_counts, labels=back_pain_labels, autopct='%1.1f%%', startangle=90, counterclock=False)
plt.axis('square');
plt.subplot(1, 2, 2)
plt.title("Relationship of Chronic Back Pain vs Hospitalization Length")
sns.boxplot(data=df, x="BackPain", y='Initial_days', color="lime")
plt.xticks(ticks=[0,1], labels = back_pain_labels)
plt.xlabel("Patient Back Pain")
plt.ylabel("Hospitalization Length");

# %%
plt.figure(figsize = [16,5])
plt.suptitle("Exploration of Patient's Vitamin D Level")
plt.subplot(1, 2, 1)
plt.title('Distribution of Patient Vitamin D Level')
bins = np.arange(5, 30, 0.20)
plt.hist(data=df, x="VitD_levels", bins=bins)
plt.xlabel('Patient Vitamin D Level')
plt.ylabel("Number of Patients");
plt.subplot(1, 2, 2)
plt.title("Relationship of Vitamin D Level vs Initial Days")
sns.regplot(data=df, x="VitD_levels", y="Initial_days", scatter_kws={'alpha' : 1/10})
plt.xlabel("Patient Vitamin D Level")
plt.ylabel("Initial Days");

# %%
plt.figure(figsize = [16,5])
plt.suptitle("Exploration of Doctor Visits to Patient")
plt.subplot(1, 2, 1)
plt.title('Distribution of Dr Visits to Patient')
bins = np.arange(0, 10, 1)
plt.hist(data=df, x="Doc_visits", bins=bins)
plt.xlabel('Number Dr Visits to Patient')
plt.ylabel("Number of Patients");
plt.subplot(1, 2, 2)
plt.title("Relationship of Dr Visits vs Initial Days")
sns.regplot(data=df, x="Doc_visits", y="Initial_days", scatter_kws={'alpha' : 1/10})
plt.xlabel("Number Dr Visits to Patient")
plt.ylabel("Initial Days");

# %%
plt.figure(figsize = [16,5])
plt.suptitle("Exploration of Patients with  Back Pain")
plt.subplot(1, 2, 1)
plt.title('Distribution of Patients with  Back Pain')
back_pain_counts = df.BackPain.value_counts()
back_pain_labels = ["No Back Pain", "Back Pain"]
plt.pie(back_pain_counts, labels=back_pain_labels, autopct='%1.1f%%', startangle=90, counterclock=False)
plt.axis('square');
plt.subplot(1, 2, 2)
plt.title("Relationship of Back Pain vs Initial Days")
sns.boxplot(data=df, x="BackPain", y='Initial_days', color="yellow")
plt.xticks(ticks=[0,1], labels = back_pain_labels)
plt.xlabel("Patient Back Pain")
plt.ylabel("Initial Days");

# %%
# get the dummies for mlr and store it in a variable
Gender_dummies = pd.get_dummies(df.Gender, dtype=int, drop_first=True)
Anxiety_dummies = pd.get_dummies(df.Anxiety, dtype=int)
Arthritis_dummies = pd.get_dummies(df.Arthritis, dtype=int, drop_first=True)
Diabetes_dummies = pd.get_dummies(df.Diabetes, dtype=int, drop_first=True)
BackPain_dummies = pd.get_dummies(df.BackPain, dtype=int, drop_first=True)

# %%
#Renaming Columns
Anxiety_dummies = Anxiety_dummies.rename(columns = {0: 'No_Anxiety', 1: 'Yes_Anxiety'})

# %%
Anxiety_dummies
# Out:
#            No_Anxiety  Yes_Anxiety
# CaseOrder
# 1                   0            1
# 2                   1            0
# 3                   1            0
# 4                   1            0
# 5                   1            0
# ...               ...          ...
# 9996                0            1
# 9997                1            0
# 9998                0            1
# 9999                1            0
# 10000               1            0
#
# [10000 rows x 2 columns]

# %%
#Renaming Columns
Arthritis_dummies = Arthritis_dummies.rename(columns = {1: 'Arthritis1',})
Arthritis_dummies
# Out:
#            Arthritis1
# CaseOrder
# 1                   1
# 2                   0
# 3                   0
# 4                   1
# 5                   0
# ...               ...
# 9996                0
# 9997                1
# 9998                0
# 9999                0
# 10000               1
#
# [10000 rows x 1 columns]

# %%
#Renaming Columns
Diabetes_dummies = Diabetes_dummies.rename(columns = {1: 'Diabetes1',})
Diabetes_dummies
# Out:
#            Diabetes1
# CaseOrder
# 1                  1
# 2                  0
# 3                  1
# 4                  0
# 5                  0
# ...              ...
# 9996               0
# 9997               1
# 9998               0
# 9999               0
# 10000              0
#
# [10000 rows x 1 columns]

# %%
#Renaming Columns
BackPain_dummies = BackPain_dummies.rename(columns = {1: 'BackPain1',})
BackPain_dummies
# Out:
#            BackPain1
# CaseOrder
# 1                  1
# 2                  0
# 3                  0
# 4                  0
# 5                  0
# ...              ...
# 9996               0
# 9997               0
# 9998               0
# 9999               1
# 10000              0
#
# [10000 rows x 1 columns]

# %%
#Multiple Regression Model starts here
#Creating data frame of variables that werent categorical and didnt need dummy variables
num_features = df[["Children", "Age", "VitD_levels", "Doc_visits","Income","TotalCharge"]]
features = pd.concat([num_features, Gender_dummies,Anxiety_dummies,Arthritis_dummies,Diabetes_dummies,BackPain_dummies], axis="columns")
#Clean Data Set

features.to_csv('output208Clean.csv', index=False)

# %%
print(features.dtypes)
# Out:
# Children         int64
# Age              int64
# VitD_levels    float64
# Doc_visits       int64
# Income           int32
# TotalCharge    float64
# Male             int32
# Nonbinary        int32
# No_Anxiety       int32
# Yes_Anxiety      int32
# Arthritis1       int32
# Diabetes1        int32
# BackPain1        int32
# dtype: object

# %%
Anxiety_dummies
# Out:
#            No_Anxiety  Yes_Anxiety
# CaseOrder
# 1                   0            1
# 2                   1            0
# 3                   1            0
# 4                   1            0
# 5                   1            0
# ...               ...          ...
# 9996                0            1
# 9997                1            0
# 9998                0            1
# 9999                1            0
# 10000               1            0
#
# [10000 rows x 2 columns]

# %%
Arthritis_dummies
# Out:
#            Arthritis1
# CaseOrder
# 1                   1
# 2                   0
# 3                   0
# 4                   1
# 5                   0
# ...               ...
# 9996                0
# 9997                1
# 9998                0
# 9999                0
# 10000               1
#
# [10000 rows x 1 columns]

# %%
Diabetes_dummies
# Out:
#            Diabetes1
# CaseOrder
# 1                  1
# 2                  0
# 3                  1
# 4                  0
# 5                  0
# ...              ...
# 9996               0
# 9997               1
# 9998               0
# 9999               0
# 10000              0
#
# [10000 rows x 1 columns]

# %%
y = df.Initial_days

# %%
X = features.assign(const=1)

# %%
print(X.dtypes)
# Out:
# Children         int64
# Age              int64
# VitD_levels    float64
# Doc_visits       int64
# Income           int32
# TotalCharge    float64
# Male             int32
# Nonbinary        int32
# No_Anxiety       int32
# Yes_Anxiety      int32
# Arthritis1       int32
# Diabetes1        int32
# BackPain1        int32
# const            int64
# dtype: object

# %%
#Multiple Regression Model 


model = sm.OLS(y, X.astype(float))
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Initial_days   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.976
# Method:                 Least Squares   F-statistic:                 3.460e+04
# Date:                Fri, 07 Jun 2024   Prob (F-statistic):               0.00
# Time:                        12:39:05   Log-Likelihood:                -28132.
# No. Observations:               10000   AIC:                         5.629e+04
# Df Residuals:                    9987   BIC:                         5.638e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Children       -0.0114      0.019     -0.610      0.542      -0.048       0.025
# ...

# %%
results.resid.std(ddof=X.shape[1])
# Out:
# 4.034674440786522

# %%
#VIF Calculation
vif_df = pd.DataFrame()

# %%
vif_df["feature"] = features.columns

# %%
vif_df["VIF"] = [variance_inflation_factor(features.values, i) for i in range(len(features.columns))]

# %%
vif_df
# Out:
#         feature        VIF
# 0      Children   1.001532
# 1           Age   1.001440
# 2   VitD_levels   1.001538
# 3    Doc_visits   1.000659
# 4        Income   1.001024
# 5   TotalCharge   1.004596
# 6          Male   1.021163
# 7     Nonbinary   1.020955
# 8    No_Anxiety  81.818979
# 9   Yes_Anxiety  39.519201
# 10   Arthritis1   1.002046
# 11    Diabetes1   1.001884
# 12    BackPain1   1.003268

# %%
#Getting rid of VitD for multicolinearity >10
#Creating data frame without Anxiety
num_features = df[["Children", "Age","Income","Doc_visits","TotalCharge"]]
features = pd.concat([num_features, Gender_dummies,Arthritis_dummies,Diabetes_dummies,BackPain_dummies], axis="columns")

# %%
#Next VIF WIthout Anxiety
vif_df = pd.DataFrame()
vif_df["feature"] = features.columns
vif_df["VIF"] = [variance_inflation_factor(features.values, i) for i in range(len(features.columns))]
vif_df
# Out:
#        feature        VIF
# 0     Children   1.905852
# 1          Age   6.545029
# 2       Income   2.872824
# 3   Doc_visits  10.841107
# 4  TotalCharge   6.030065
# 5         Male   1.899912
# 6    Nonbinary   1.041610
# 7   Arthritis1   1.543226
# 8    Diabetes1   1.369774
# 9    BackPain1   1.685179

# %%
#Getting rid of Doc_Visits for multicolinearity >10
#Creating data frame without doc visits
num_features = df[["Children", "Age","Income","TotalCharge"]]
features = pd.concat([num_features, Gender_dummies,Arthritis_dummies,Diabetes_dummies,BackPain_dummies], axis="columns")

# %%
#Next VIF WIthout Doc_Visits
vif_df = pd.DataFrame()
vif_df["feature"] = features.columns
vif_df["VIF"] = [variance_inflation_factor(features.values, i) for i in range(len(features.columns))]
vif_df
# Out:
#        feature       VIF
# 0     Children  1.863905
# 1          Age  5.034952
# 2       Income  2.665954
# 3  TotalCharge  4.943931
# 4         Male  1.843615
# 5    Nonbinary  1.039839
# 6   Arthritis1  1.524094
# 7    Diabetes1  1.353738
# 8    BackPain1  1.656803

# %%
#MLR Model Reduction - P values
y = df.Initial_days
X = features.assign(const=1)
model = sm.OLS(y, X.astype(float))
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Initial_days   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.976
# Method:                 Least Squares   F-statistic:                 4.544e+04
# Date:                Fri, 07 Jun 2024   Prob (F-statistic):               0.00
# Time:                        12:40:10   Log-Likelihood:                -28207.
# No. Observations:               10000   AIC:                         5.643e+04
# Df Residuals:                    9990   BIC:                         5.651e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Children       -0.0134      0.019     -0.711      0.477      -0.050       0.023
# ...

# %%
##Removing CHildren (.477)
num_features = df[[ "Age","Income","TotalCharge"]]
features = pd.concat([num_features, Gender_dummies,Arthritis_dummies,Diabetes_dummies,BackPain_dummies], axis="columns")
y = df.Initial_days
X = features.assign(const=1)
model = sm.OLS(y, X.astype(float))
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Initial_days   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.976
# Method:                 Least Squares   F-statistic:                 5.113e+04
# Date:                Fri, 07 Jun 2024   Prob (F-statistic):               0.00
# Time:                        12:40:21   Log-Likelihood:                -28207.
# No. Observations:               10000   AIC:                         5.643e+04
# Df Residuals:                    9991   BIC:                         5.650e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Age             0.0002      0.002      0.108      0.914      -0.004       0.004
# ...

# %%
##Removing Age (.863)
num_features = df[[ "Income","TotalCharge"]]
features = pd.concat([num_features, Gender_dummies,Arthritis_dummies,Diabetes_dummies,BackPain_dummies], axis="columns")
y = df.Initial_days
X = features.assign(const=1)
model = sm.OLS(y, X.astype(float))
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Initial_days   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.976
# Method:                 Least Squares   F-statistic:                 5.844e+04
# Date:                Fri, 07 Jun 2024   Prob (F-statistic):               0.00
# Time:                        12:40:23   Log-Likelihood:                -28207.
# No. Observations:               10000   AIC:                         5.643e+04
# Df Residuals:                    9992   BIC:                         5.649e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Income       1.552e-06   1.43e-06      1.089      0.276   -1.24e-06    4.35e-06
# ...

# %%
##Removing Income (.273)
num_features = df[[ "TotalCharge"]]
features = pd.concat([num_features, Gender_dummies,Arthritis_dummies,Diabetes_dummies,BackPain_dummies], axis="columns")
y = df.Initial_days
X = features.assign(const=1)
model = sm.OLS(y, X.astype(float))
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Initial_days   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.976
# Method:                 Least Squares   F-statistic:                 6.818e+04
# Date:                Fri, 07 Jun 2024   Prob (F-statistic):               0.00
# Time:                        12:40:26   Log-Likelihood:                -28208.
# No. Observations:               10000   AIC:                         5.643e+04
# Df Residuals:                    9993   BIC:                         5.648e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# TotalCharge     0.0119   1.87e-05    639.327      0.000       0.012       0.012
# ...

# %%
#Removing Gender (MALE + NONbinary) (.319,.591)
num_features = df[[ "TotalCharge"]]
features = pd.concat([num_features,Arthritis_dummies,Diabetes_dummies,BackPain_dummies], axis="columns")
y = df.Initial_days
X = features.assign(const=1)
model = sm.OLS(y, X.astype(float))
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Initial_days   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.976
# Method:                 Least Squares   F-statistic:                 1.023e+05
# Date:                Fri, 07 Jun 2024   Prob (F-statistic):               0.00
# Time:                        12:40:28   Log-Likelihood:                -28209.
# No. Observations:               10000   AIC:                         5.643e+04
# Df Residuals:                    9995   BIC:                         5.646e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# TotalCharge     0.0119   1.87e-05    639.358      0.000       0.012       0.012
# ...

# %%
results.resid.std(ddof=X.shape[1])
# Out:
# 4.0639803125145395

# %%
#Final Reduced Regression Model
y = df.Initial_days
X = features.assign(const=1)
model = sm.OLS(y, X.astype(float))
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Initial_days   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.976
# Method:                 Least Squares   F-statistic:                 1.023e+05
# Date:                Fri, 07 Jun 2024   Prob (F-statistic):               0.00
# Time:                        12:40:36   Log-Likelihood:                -28209.
# No. Observations:               10000   AIC:                         5.643e+04
# Df Residuals:                    9995   BIC:                         5.646e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# TotalCharge     0.0119   1.87e-05    639.358      0.000       0.012       0.012
# ...

# %%
results.resid.std(ddof=X.shape[1])
# Out:
# 4.0639803125145395

# %%
#Analysis of MLR models
fig = plt.figure(figsize = [16,8])
sm.graphics.plot_regress_exog(results, 'TotalCharge', fig=fig);
# Out:
# C:\Users\jefft\anaconda3\envs\JeffPandasNumpy\Lib\site-packages\statsmodels\graphics\regressionplots.py:430: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   fig = abline_plot(0, fitted_line.params[0], color='k', ax=ax)

# %%
#Analysis of MLR models
fig = plt.figure(figsize = [16,8])
sm.graphics.plot_regress_exog(results, 'Arthritis1', fig=fig);

# %%
#Analysis of MLR models
fig = plt.figure(figsize = [16,8])
sm.graphics.plot_regress_exog(results, 'Diabetes1', fig=fig);

# %%
#Analysis of MLR models
fig = plt.figure(figsize = [16,8])
sm.graphics.plot_regress_exog(results, 'BackPain1', fig=fig);

# %%
#Clean Data Set

df.to_csv('output208Clean.csv', index=False)
